# %%
import os, sys

# Add the project root (one level above notebooks/) to sys.path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print("Added to sys.path:", project_root)
# Out:
# Added to sys.path: /mnt/c/dev/ai_projects/rag_notebook

# %%
from app.retriever import load_retriever
load_retriever()
# Out:
# 'retriever ready'

# %%
import os, sys
print("CWD:", os.getcwd())
print("First few sys.path entries:")
for p in sys.path[:5]:
    print("  ", p)
# Out:
# CWD: /mnt/c/dev/ai_projects/rag_notebook/notebooks
# First few sys.path entries:
#    /home/joelb/miniconda3/envs/ai_env/lib/python311.zip
#    /home/joelb/miniconda3/envs/ai_env/lib/python3.11
#    /home/joelb/miniconda3/envs/ai_env/lib/python3.11/lib-dynload
#
#    /home/joelb/miniconda3/envs/ai_env/lib/python3.11/site-packages
